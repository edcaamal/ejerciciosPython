# %% [markdown]
# <a href="https://colab.research.google.com/github/edcaamal/ejerciciosPython/blob/main/pngColab_01.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt
import cv2  #OpenCV Phyton
import numpy as np

# %%
img = cv2.imread("/content/ardilla.png")
plt.imshow(img)
plt.show()

# %%
img = cv2.imread("/content/jabali.jpg")
plt.imshow(img)
plt.show()

# %%
animales =["Ardilla", "Caracol","Jabalí", "Jaguar"]
imgAnimales =["ardilla.png", "caracol.png", "jabali.jpg",
              "jaguar.jpg"]

# %%
# Validar con 0, 1, 2, 3
idAnimal = 2
tamanoLista = len(animales)
nombreAnimal  = animales[idAnimal]
nombreArchivo = imgAnimales[idAnimal] 
print(nombreAnimal, nombreArchivo)

img = cv2.imread("/content/"+nombreArchivo)
plt.imshow(img)
plt.show()
# Out:
# Jabali jabali.jpg

# %%
idAnimal = 3
tamanoLista = len(animales)
if (idAnimal < tamanoLista):
  nombreAnimal  = animales[idAnimal]
  nombreArchivo = imgAnimales[idAnimal] 
  print(nombreAnimal, nombreArchivo)

  img = cv2.imread("/content/"+nombreArchivo)
  plt.imshow(img)
  plt.show()
else:
  print("id fuera del rango el limite es del 0 al ", idAnimal-1)
# Out:
# Jaguar jaguar.jpg
