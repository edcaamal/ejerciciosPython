# %% [markdown]
# <a href="https://colab.research.google.com/github/edcaamal/ejerciciosPython/blob/main/pngColab_02.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt
import cv2  #OpenCV Phyton
import numpy as np

# %%
frutas =["Aguacate", "Cereza","Durazno", "Fresa"]
imgFrutas =["aguacate.jpg", "cereza.jpg", "durazno.png",
              "fresa.png"]

# %%
id = 2
tamanoLista = len(frutas)
if (id < tamanoLista):
  nombre  = frutas[id]
  nombreArchivo = imgFrutas[id] 
  print(nombre, nombreArchivo)

  img = cv2.imread("/content/frutas/"+nombreArchivo)
  plt.imshow(img)
  plt.show()
else:
  print("id fuera del rango el limite es del 0 al ", idAnimal-1)
# Out:
# Durazno durazno.png

# %%
class objetos:
  def __init__(self, nombre, imagen, ruta):
    self.nombre = nombre
    self.imagen = imagen
    self.ruta = ruta
  def __str__(self):
    return f"{self.nombre}.{self.imagen}.{self.ruta}"
  def graficarImagen(self):
      img = cv2.imread(self.ruta+self.imagen)
      plt.imshow(img)
      plt.show()

# %%
misFrutas = []
misFrutas.append(objetos("Aguacate", "aguacate.jpg","/content/frutas/"))
misFrutas.append(objetos("Cereza", "cereza.jpg","/content/frutas/"))
print(misFrutas[0])
misFrutas[1].graficarImagen()
# Out:
# Aguacate.aguacate.jpg./content/frutas/

# %%
misFrutas.append(objetos("ardilla", "ardilla.png","/content/animales/"))
print(misFrutas[2])
misFrutas[2].graficarImagen()
# Out:
# ardilla.ardilla.png./content/animales/

# %%
buscar = input("Teclee el nombre del Objeto a buscar ")
buscar = buscar.lower()
idEncontrado = -1
id= 0
for objeto in misFrutas:
  if objeto.nombre.lower() == buscar:
     idEncontrado = id
  id += 1
misFrutas[idEncontrado].graficarImagen()
# Out:
# Teclee el nombre del Objeto a buscar AGUACATE
